# %% [markdown]
# $$
# \\
# \\
# \LARGE\text{Correlation between crypto and} \\
# \LARGE\text{traditional assets} \\
# \\
# $$
#
# $$ \text{[FINM 31200] Blockchains and Cryptoassets for Finance} $$
# $$ \text{Autumn 2023 | Dr. Brian Boonstra, Dr. William Cottrell and Dr. Christopher Ellison } $$
# $$ \text{Final Project} $$
#
# \begin{aligned}
# \small\text{Authors: Arvin Wang, }\small\text{Charlotte Wang, }&\small\text{Mia Liang, }\small\text{ and Vidhan Ajmera}
# \end{aligned}
#
# $$
# \begin{aligned}
# ^1 \scriptsize\text{zijingwang@uchicago.edu }&\scriptsize\text{| Student ID: } \\
# ^2 \scriptsize\text{jingranw@uchicago.edu }&\scriptsize\text{| Student ID: 12375030 } \\
# ^3 \scriptsize\text{shiyao@uchicago.edu }&\scriptsize\text{| Student ID: 12375239 } \\
# ^4 \scriptsize\text{vidhanajmera@uchicago.edu }&\scriptsize\text{| Student ID: 12375227} \\
# \\
# \end{aligned}
# $$

# %% [markdown]
# $\textbf{Abstract. }$
# $\text{In this paper, we explore correlations between crypto currencies(Bitcoin) and}$
# $\text{other traditional asset classes such as bond, equities, real estate etc.}$
#
#
# $\textbf{Keywords: }$
# $\text{Crypto currency, End-of-day Pricing, Trading Volume, Covariance, Correlation.}$
#
# <br>

# %% [markdown]
# $\large\textbf{1. Define data scope}$

# %% [markdown]
# $\text{For the analysis, we selected 20 US ETFs}^4\text{ across 6 different asset classes:}$
#
# <br>
# <table>
#     <tr>
#         <td style="text-align:left">$\textbf{Asset Class}$</td>
#         <td style="text-align:left">$\textbf{Sub Asset Class}$</td>
#         <td style="text-align:left">$\textbf{ETF Name}$</td>
#         <td style="text-align:left">$\textbf{ETF Symbol}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{Cash}$</td>
#         <td style="text-align:left">$\text{Cash}$</td>
#         <td style="text-align:left">$\text{SPDR Bloomberg 1-3 Month T-Bill ETF}$</td>
#         <td style="text-align:left">$\text{BIL}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{Commodities}$</td>
#         <td style="text-align:left">$\text{Agriculture}$</td>
#         <td style="text-align:left">$\text{Invesco DB Agriculture Fund}$</td>
#         <td style="text-align:left">$\text{DBA}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{Crude Oil}$</td>
#         <td style="text-align:left">$\text{United States Oil Fund LP}$</td>
#         <td style="text-align:left">$\text{USO}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{Gold}$</td>
#         <td style="text-align:left">$\text{SPDR Gold Shares}$</td>
#         <td style="text-align:left">$\text{GLD}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{Livestock}$</td>
#         <td style="text-align:left">$\text{iPath Series B Bloomberg Livestock Subindex Total Return ETN}$</td>
#         <td style="text-align:left">$\text{COW}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{Natural Gas}$</td>
#         <td style="text-align:left">$\text{United States Natural Gas Fund LP}$</td>
#         <td style="text-align:left">$\text{UNG}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{Silver}$</td>
#         <td style="text-align:left">$\text{iShares Silver Trust}$</td>
#         <td style="text-align:left">$\text{SLV}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{Equities}$</td>
#         <td style="text-align:left">$\text{DM-Equities}$</td>
#         <td style="text-align:left">$\text{Vanguard Developed Markets Index Fund ETF}$</td>
#         <td style="text-align:left">$\text{VEA}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{EM-Equities}$</td>
#         <td style="text-align:left">$\text{Vanguard Emerging Markets Stock Index Fund ETF}$</td>
#         <td style="text-align:left">$\text{VWO}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{FM-Equities}$</td>
#         <td style="text-align:left">$\text{iShares MSCI Frontier 100 ETF}$</td>
#         <td style="text-align:left">$\text{FM}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{US-Equities}$</td>
#         <td style="text-align:left">$\text{iShares Core S&P Total US Stock Market ETF}$</td>
#         <td style="text-align:left">$\text{ITOT}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{Fixed Income}$</td>
#         <td style="text-align:left">$\text{EM Bonds}$</td>
#         <td style="text-align:left">$\text{iShares JP Morgan USD Emerging Markets Bond ETF}$</td>
#         <td style="text-align:left">$\text{EMB}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{International Bonds}$</td>
#         <td style="text-align:left">$\text{Vanguard Total International Bond ETF}$</td>
#         <td style="text-align:left">$\text{BNDX}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{US Corporate Bonds}$</td>
#         <td style="text-align:left">$\text{iShares iBoxx \$ Investment Grade Corporate Bond ETF}$</td>
#         <td style="text-align:left">$\text{LQD}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{US Corporate High Yield}$</td>
#         <td style="text-align:left">$\text{iShares iBoxx \$ High Yield Corporate Bond ETF}$</td>
#         <td style="text-align:left">$\text{HYG}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{US MBS}$</td>
#         <td style="text-align:left">$\text{iShares MBS ETF}$</td>
#         <td style="text-align:left">$\text{MBB}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{US TIPS}$</td>
#         <td style="text-align:left">$\text{iShares TIPS Bond ETF}$</td>
#         <td style="text-align:left">$\text{TIP}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{US Short term Treasuries}$</td>
#         <td style="text-align:left">$\text{iShares 1-3 Year Treasury Bond ETF}$</td>
#         <td style="text-align:left">$\text{SHY}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{US Mid term Treasuries}$</td>
#         <td style="text-align:left">$\text{iShares 20+ Year Treasury Bond ETF}$</td>
#         <td style="text-align:left">$\text{IEI}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{}$</td>
#         <td style="text-align:left">$\text{US Mid term Treasuries}$</td>
#         <td style="text-align:left">$\text{iShares 3-7 Year Treasury Bond ETF}$</td>
#         <td style="text-align:left">$\text{TLT}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{Private Equity}$</td>
#         <td style="text-align:left">$\text{Private Equity}$</td>
#         <td style="text-align:left">$\text{Invesco Global Listed Private Equity ETF}$</td>
#         <td style="text-align:left">$\text{PSP}$</td>
#     </tr>
#     <tr>
#         <td style="text-align:left">$\text{Real Estate}$</td>
#         <td style="text-align:left">$\text{Real Estate}$</td>
#         <td style="text-align:left">$\text{Vanguard Real Estate ETF}$</td>
#         <td style="text-align:left">$\text{VNQ}$</td>
#     </tr>
#
# </table>
# <br>

# %% [markdown]
# **Documentation**
#
# End of Day US Stock Prices (EOD)
# https://data.nasdaq.com/databases/EOD/documentation

# %% [markdown]
# $\large\textbf{2 }\quad\large\textbf{Import Libraries}$

# %%
import numpy as np
import pandas as pd
import nasdaqdatalink
import scipy.stats as ss
import seaborn as sns
from functools import lru_cache
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.gofplots import qqplot
import datetime
import pandas_datareader as pdr
import warnings
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [15,10]
warnings.filterwarnings('ignore')

# %%
def fetch_quandl(secs,start_date,end_date,columns):
    # Retrieve data using quandl.get_table
    nasdaqdatalink.ApiConfig.api_key = '-BaoH_GauM_J-k12p3mN'
    data = nasdaqdatalink.get_table('QUOTEMEDIA/PRICES', ticker = secs, qopts={"columns":["ticker","date","adj_close","adj_volume"]}, date = { 'gte': start_date, 'lte': end_date })    
    return data

# %% [markdown]
# $\textbf{Get EOD (end of day) data for Traditional ETFs from Quandl}$

# %%
secs = ['BIL','BNDX','ITOT','DBA','EMB',
        'FM','GLD','VWO','HYG','LQD',
        'MBB','PSP','SCHB','SLV','TIP',
        'UNG','USO','VEA','VNQ','SHY',
       'IEI', 'TLT', 'SPY']
start_date,end_date = '2017-11-15','2023-11-15'
etf_data = pd.DataFrame()
for i in range(len(secs)):
    if i ==0: 
        etf_data = fetch_quandl(secs[i],start_date,end_date,('adj_close','adj_volume'))
    
    else:
        etf_data = pd.concat([etf_data, fetch_quandl(secs[i],start_date,end_date,('adj_close','adj_volume'))], axis = 0, join = 'inner')
etf_data
# Out:
#      ticker       date   adj_close  adj_volume
# None
# 0       BIL 2023-11-15   91.201932  10534732.0
# 1       BIL 2023-11-14   91.182024  11102209.0
# 2       BIL 2023-11-13   91.172069   6142845.0
# 3       BIL 2023-11-10   91.162115   5552980.0
# 4       BIL 2023-11-09   91.152160  11880432.0
# ...     ...        ...         ...         ...
# 1505    SPY 2017-11-21  234.723236  69078940.0
# 1506    SPY 2017-11-20  233.197476  47950881.0
# 1507    SPY 2017-11-17  232.800237  75725627.0
# 1508    SPY 2017-11-16  233.486377  67639490.0
# 1509    SPY 2017-11-15  231.518237  80811525.0
#
# [34730 rows x 4 columns]

# %%
fig, axs = plt.subplots(23, 1, figsize=(20, 75))

for i,sec in enumerate(secs):
    df = etf_data[etf_data['ticker']==sec]
    axs[i].plot(df['date'], df['adj_close'], label=sec)
    axs[i].set_title(f'Historical prices ' + str(sec),fontsize=15)
    axs[i].grid(linestyle='solid',color='grey', linewidth=0.6)
    axs[i].set_xlabel('Time',fontsize = 10)
    axs[i].legend(fontsize = 12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bitcoin

# %%
Total Bitcoins	TOTBC
Bitcoin Market Price USD	MKPRU
Bitcoin Median Transaction Conf. Time	ATRCT
Bitcoin Average Block Size	AVBLS
Bitcoin api.blockchain Size	BLCHS
Bitcoin Cost Per Transaction	CPTRA
Bitcoin Cost % of Transaction Volume	CPTRV
Bitcoin Difficulty	DIFF
Bitcoin Estimated Transaction Volume	ETRAV
Bitcoin Estimated Transaction Vol. USD	ETRVU
Bitcoin Hash Rate	HRATE
Bitcoin Miners Revenue	MIREV
Bitcoin Market Capitalization	MKTCP
Bitcoin My Wallet Number of Tx Per Day	MWNTD
Bitcoin My Wallet Number of Users	MWNUS
Bitcoin My Wallet Transaction Volume	MWTRV
Bitcoin Number of Unique Addr. Used	NADDU
Bitcoin Number of Transactions	NTRAN
Bitcoin Total Number of Transactions	NTRAT
Bitcoin Number of Tx per Block	NTRBL
Bitcoin Tx Excluding Popular Addresses	NTREP
Bitcoin Total Output Volume	TOUTV
Bitcoin Total Transaction Fees	TRFEE
Bitcoin Total Transaction Fees USD	TRFUS
Bitcoin USD Exchange Trade Volume	TRVOU
# Out:
#   File "/var/folders/zg/n5n_49n11cn3mqk7j8f_6kcm0000gn/T/ipykernel_13427/3617438726.py", line 1
#     Total Bitcoins	TOTBC
#           ^
# SyntaxError: invalid syntax

# %%
bitcoin_price = nasdaqdatalink.get_table('QDL/BCHAIN',date={ 'gte': start_date, 'lte': end_date }, code='MKPRU').set_index('date')
bitcoin_total = nasdaqdatalink.get_table('QDL/BCHAIN',date={ 'gte': start_date, 'lte': end_date }, code='TOTBC').set_index('date')
bitcoin_cost_per_transaction = nasdaqdatalink.get_table('QDL/BCHAIN',date={ 'gte': start_date, 'lte': end_date }, code='CPTRA').set_index('date')
bitcoin_difficulty = nasdaqdatalink.get_table('QDL/BCHAIN',date={ 'gte': start_date, 'lte': end_date }, code='DIFF').set_index('date')

# %%
plt.plot(bitcoin_price['value'], label= "Bitcoin price in USD")
plt.legend()
None

# %%
bitcoin_price.drop(['code'],axis = 1, inplace= True)
bitcoin_price.rename(columns={'value': 'BTC'}, inplace = True)

# %%
import yfinance as yf
eth_price = yf.download('ETH-USD', start=start_date, end=end_date)
eth_price.drop(['Open', 'High', 'Low', 'Close', 'Volume'],axis = 1, inplace= True)
eth_price.rename(columns={'Date': 'date','Adj Close': 'ETH'}, inplace = True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.plot(eth_price['ETH'], label= "Bitcoin price in USD")
plt.legend()
None

# %%
import pandas as pd
import matplotlib.pyplot as plt


def plot_qq(dataframe):
    """
    This function takes a DataFrame with daily returns and plots QQ plots for each column.

    Parameters:
    dataframe (pd.DataFrame): A DataFrame where each column represents daily returns of different assets.
    """
    plt.figure(figsize=(5, 3))
    qqplot(dataframe, line='q')
    plt.title(f'QQ Plot for ')
    plt.show()

# %%
plot_qq(bit_ret)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/zg/n5n_49n11cn3mqk7j8f_6kcm0000gn/T/ipykernel_13427/2267157075.py in <module>
# ----> 1 plot_qq(bit_ret)
#
# NameError: name 'bit_ret' is not defined

# %%
df_returns = pd.DataFrame()
my_dict = {}
for i,sec in enumerate(secs):
    df = etf_data[etf_data['ticker']==sec].set_index("date")
    df = df.sort_index()
    my_dict[sec] = len(df['adj_close'])
    df.drop(['ticker', 'adj_volume'],axis = 1, inplace= True)
    df.rename(columns={'adj_close': str(sec)}, inplace = True)
    df = df.pct_change()
    if df_returns.empty:
        df_returns = df
    else:
        df_returns = df_returns.merge(df, how='outer', left_index=True, right_index=True)
df_returns = df_returns.merge(bitcoin_price.sort_index(), how='outer', left_index=True, right_index=True)
df_returns = df_returns.merge(eth_price.sort_index(), how='outer', left_index=True, right_index=True)
df_returns['BTC'] = df_returns['BTC'].pct_change()
df_returns['ETH'] = df_returns['ETH'].pct_change()

# %%
df_returns = df_returns.dropna()
df_returns.head()
# Out:
#                  BIL      BNDX      ITOT       DBA       EMB        FM  \
# 2017-11-16  0.000219 -0.000182  0.009551 -0.001572  0.004015  0.014049
# 2017-11-17 -0.000219  0.000182 -0.001183  0.001049  0.001826 -0.000945
# 2017-11-20  0.000219  0.000546  0.001522 -0.004193 -0.000260  0.008509
# 2017-11-21  0.000219  0.000909  0.007262  0.000526  0.001389  0.002500
# 2017-11-22  0.000000  0.001453 -0.000671  0.008417  0.004247  0.023379
#
#                  GLD       VWO       HYG       LQD  ...       UNG       USO  \
# 2017-11-16 -0.000082  0.017792  0.009806 -0.001162  ... -0.003160 -0.001803
# 2017-11-17  0.012026  0.005603 -0.000685  0.001247  ...  0.014263  0.025294
# 2017-11-20 -0.012616  0.004234  0.000229  0.000000  ... -0.025000 -0.006167
# 2017-11-21  0.001649  0.012428  0.002057  0.003321  ... -0.006410  0.010638
# 2017-11-22  0.009217  0.003288  0.001597  0.003889  ... -0.016129  0.017544
#
#                  VEA       VNQ       SHY       IEI       TLT       SPY  \
# 2017-11-16  0.009629  0.008302  0.000119 -0.001220 -0.008692  0.008501
# 2017-11-17 -0.003860 -0.004352 -0.000594  0.000489  0.007413 -0.002939
# 2017-11-20  0.001824 -0.002953 -0.000357 -0.001383 -0.000396  0.001706
# 2017-11-21  0.007736  0.007464 -0.000238 -0.000815  0.003166  0.006543
# 2017-11-22  0.003387 -0.002235  0.000833  0.002610  0.003235 -0.000885
#
#                  BTC       ETH
# 2017-11-16  0.070342 -0.007298
# 2017-11-17  0.006876  0.004442
# 2017-11-20  0.005253  0.034832
# 2017-11-21  0.001252 -0.017258
# 2017-11-22  0.025836  0.056190
#
# [5 rows x 25 columns]

# %%
df_returns = df_returns.dropna()

# %%
def performance_summary(return_data, annualization = 252):
    """ 
        Returns the Performance Stats for given set of returns
        Inputs: 
            return_data - DataFrame with Date index and Monthly Returns for different assets/strategies.
        Output:
            summary_stats - DataFrame with annualized mean return, vol, sharpe ratio. Skewness, Excess Kurtosis, Var (0.5) and
                            CVaR (0.5) and drawdown based on monthly returns. 
    """
    summary_stats = return_data.mean().to_frame('Mean').apply(lambda x: x*annualization)
    summary_stats['Volatility'] = return_data.std().apply(lambda x: x*np.sqrt(annualization))
    summary_stats['Sharpe Ratio'] = summary_stats['Mean']/summary_stats['Volatility']

    summary_stats['Skewness'] = return_data.skew()
    summary_stats['Excess Kurtosis'] = return_data.kurtosis()
    summary_stats['VaR (0.05)'] = return_data.quantile(.05, axis = 0)
    summary_stats['CVaR (0.05)'] = return_data[return_data <= return_data.quantile(.05, axis = 0)].mean()
    
    wealth_index = 1000*(1+return_data).cumprod()
    previous_peaks = wealth_index.cummax()
    drawdowns = (wealth_index - previous_peaks)/previous_peaks

    summary_stats['Max Drawdown'] = drawdowns.min()
    summary_stats['Peak'] = [previous_peaks[col][:drawdowns[col].idxmin()].idxmax() for col in previous_peaks.columns]
    summary_stats['Bottom'] = drawdowns.idxmin()
    
    recovery_date = []
    for col in wealth_index.columns:
        prev_max = previous_peaks[col][:drawdowns[col].idxmin()].max()
        recovery_wealth = pd.DataFrame([wealth_index[col][drawdowns[col].idxmin():]]).T
        recovery_date.append(recovery_wealth[recovery_wealth[col] >= prev_max].index.min())
    summary_stats['Recovery'] = recovery_date
    
    return summary_stats

# %%
performance_summary(df_returns)
# Out:
#           Mean  Volatility  Sharpe Ratio  Skewness  Excess Kurtosis  \
# BIL   0.013252    0.003630      3.650761 -7.224235        95.970266
# BNDX  0.006298    0.044417      0.141788 -0.556301         8.072192
# ITOT  0.123709    0.208041      0.594640 -0.536091        11.425296
# DBA   0.038688    0.129736      0.298204 -0.239656         1.706859
# EMB  -0.002299    0.116003     -0.019821 -2.259552        32.281027
# FM    0.016042    0.168068      0.095450 -2.382854        27.255675
# GLD   0.077250    0.141148      0.547299 -0.193192         3.351017
# VWO   0.032774    0.211237      0.155152 -0.769226         9.952041
# HYG   0.025570    0.098064      0.260751  0.117514        22.166223
# LQD   0.007461    0.100152      0.074501  0.628940        26.785722
# MBB  -0.006668    0.056172     -0.118711  0.001138        13.757893
# PSP   0.071561    0.246815      0.289939 -0.604548        10.820963
# SCHB  0.124573    0.209734      0.593955 -0.558307        12.520298
# SLV   0.088071    0.280418      0.314070 -0.188987         7.177682
# TIP   0.015990    0.065817      0.242941  0.366321        14.590376
# UNG  -0.069743    0.557658     -0.125064  0.056627         2.482993
# USO   0.054657    0.420419      0.130006 -1.352756        15.996416
# VEA   0.050081    0.190268      0.263211 -0.957481        14.570908
# VNQ   0.051217    0.237285      0.215847 -1.172362        19.507223
# SHY   0.008274    0.016801      0.492471  0.838980        10.020794
# IEI   0.002474    0.042091      0.058773  0.391355         3.518034
# TLT  -0.024703    0.164023     -0.150608  0.219478         5.385336
# SPY   0.131727    0.203685      0.646722 -0.530462        11.163613
# BTC   0.260705    0.633067      0.411813 -0.409060         9.354999
# ETH   0.323295    0.809677      0.399288 -0.302906         5.804666
#
#       VaR (0.05)  CVaR (0.05)  Max Drawdown       Peak     Bottom   Recovery
# BIL    -0.000109    -0.000386     -0.003709 2022-11-29 2022-12-19 2023-01-26
# BNDX   -0.004320    -0.006547     -0.162272 2020-12-11 2022-10-20        NaT
# ITOT   -0.020309    -0.031833     -0.350039 2020-02-19 2020-03-23 2020-08-12
# DBA    -0.012052    -0.018436     -0.311762 2018-03-05 2020-06-26 2021-05-06
# EMB    -0.009777    -0.017480     -0.287503 2021-09-02 2022-10-20        NaT
# FM     -0.015219    -0.025728     -0.416350 2018-01-22 2020-03-23 2021-06-04
# GLD    -0.014667    -0.020605     -0.220022 2020-08-06 2022-09-26        NaT
# VWO    -0.019287    -0.030381     -0.363894 2018-01-26 2020-03-23 2020-11-09
# HYG    -0.008160    -0.014536     -0.220313 2020-02-20 2020-03-23 2020-11-04
# LQD    -0.008925    -0.014089     -0.254145 2021-09-22 2022-10-20        NaT
# MBB    -0.005700    -0.008863     -0.176390 2021-02-09 2023-10-19        NaT
# PSP    -0.023602    -0.036722     -0.471531 2021-11-05 2022-10-12        NaT
# SCHB   -0.020533    -0.032113     -0.352745 2020-02-19 2020-03-23 2020-08-12
# SLV    -0.025553    -0.040415     -0.393333 2020-08-10 2022-09-01        NaT
# TIP    -0.005735    -0.009584     -0.159451 2021-11-09 2023-10-06        NaT
# UNG    -0.057023    -0.079801     -0.848932 2018-11-14 2023-06-01        NaT
# USO    -0.037540    -0.065446     -0.867537 2018-10-03 2020-04-28        NaT
# VEA    -0.016953    -0.028031     -0.357353 2018-01-26 2020-03-23 2020-11-16
# VNQ    -0.021477    -0.035054     -0.424163 2020-02-21 2020-03-23 2021-04-15
# SHY    -0.001477    -0.002436     -0.057068 2021-08-02 2022-10-20        NaT
# IEI    -0.004185    -0.005979     -0.146005 2020-08-04 2022-10-20        NaT
# TLT    -0.016181    -0.022233     -0.483499 2020-08-04 2023-10-19        NaT
# SPY    -0.019626    -0.031362     -0.336999 2020-02-19 2020-03-23 2020-08-10
# BTC    -0.059965    -0.093217     -0.879305 2017-12-15 2020-03-17        NaT
# ETH    -0.076745    -0.119338     -0.926426 2018-01-09 2018-12-14 2021-05-03

# %%
zz = pd.DataFrame(index = etf_data[etf_data['ticker']== 'SPY']['date'] )
# zz['RET'] = etf_data[etf_data['ticker']== 'SPY']['adj_close'].pct_change()

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np

def plot_qq_plots(returns_df):
    """
    Generate Q-Q plots for the returns of various assets stored in a DataFrame.

    Parameters:
    - returns_df: pandas DataFrame containing returns of multiple assets.

    Returns:
    - None (plots are displayed).
    """
    num_assets = len(returns_df.columns)

    # Create subplots based on the number of assets
    fig, axes = plt.subplots(2, 2, figsize=(10, 10))
    for i, asset in enumerate(returns_df.columns):
        for j in range(2):
            ax = axes[i,j]

            # Generate Q-Q plot for the asset's returns
            sm.qqplot(returns_df[asset].dropna(), line='s', ax=ax)
            ax.set_title(f'Q-Q Plot for {asset} Returns')
        
    plt.tight_layout()
    plt.show()

# Example usage:
# Assuming you have a DataFrame 'returns_df' with columns for different asset returns.
# plot_qq_plots(df_returns)

# %%
len(df_returns.columns)
# Out:
# 25

# %%
df_qqplots = df_returns[['BTC', 'ETH', 'SPY', 'GLD']]

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
sm.qqplot(df_returns['USO'].dropna(), line='s', ax=axes[0,0])
axes[0,0].set_title(f'Q-Q Plot for Crude Oil Returns')
axes[0,0].set_ylabel('Crude Oil Quantile')

sm.qqplot(df_returns['VNQ'].dropna(), line='s', ax=axes[0,1])
axes[0,1].set_title(f'Q-Q Plot for Real Estate ETF Returns')
axes[0,1].set_ylabel('Real Estate ETF Quantile')

sm.qqplot(df_returns['SHY'].dropna(), line='s', ax=axes[1,0])
axes[1,0].set_title(f'Q-Q Plot for USB ST ETF Returns')
axes[1,0].set_ylabel('USB ST ETF Quantile')

sm.qqplot(df_returns['IEI'].dropna(), line='s', ax=axes[1,1])
axes[1,1].set_title(f'Q-Q Plot for USB LT ETF Returns')
axes[1,1].set_ylabel('USB LT ETF Quantile')

plt.tight_layout()
plt.savefig('qqplot1.png', dpi=300)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def plot_ewm_correlation(returns_df, asset_pairs,ETF, span=30):
    """
    Plot the exponentially weighted correlation of returns for asset pairs.

    Parameters:
    - returns_df: pandas DataFrame containing returns of multiple assets with datetime index.
    - asset_pairs: List of tuples containing pairs of asset names (e.g., [("Asset1", "Asset2"), ("Asset3", "Asset4")])
    - span: Span parameter for the exponential weighting (default is 30).

    Returns:
    - None (plots are displayed).
    """
    if not isinstance(returns_df.index, pd.DatetimeIndex):
        raise ValueError("The DataFrame must have a datetime index.")
    fig, ax = plt.subplots(figsize=(25, 4))
    for asset1, asset2 in asset_pairs:
        if asset1 not in returns_df.columns or asset2 not in returns_df.columns:
            raise ValueError(f"One or both of the assets '{asset1}' and '{asset2}' not found in DataFrame.")
        ewm_corr = returns_df[asset1].ewm(span=span).corr(returns_df[asset2])
        ax.plot(ewm_corr, label=f"{asset1} vs. {asset2}")
    ax.set_title(f"Exponentially Weighted Correlation against {ETF} Returns (Span={span})")
    ax.set_xlabel("Date")
    ax.set_ylabel("EMW Correlation")
    ax.legend()
    ax.grid(axis = "y", linestyle = "dashed")
    plt.tight_layout()
    plt.savefig(f'{ETF}.png', dpi=300)
    plt.show()

# %%
plot_ewm_correlation(df_returns, [('BTC', 'ETH')],"BTC-ETH", span=30)

# %%
plot_ewm_correlation(df_returns, [('BTC', 'SPY'), ('ETH', 'SPY')],"S&P 500 ETF", span=30)

# %%
plot_ewm_correlation(df_returns, [('BTC', 'GLD'), ('ETH', 'GLD')],"Gold ETF", span=30)

# %%
plot_ewm_correlation(df_returns, [('BTC', 'USO'), ('ETH', 'USO')],"US Oil ETF", span=30)

# %%
plot_ewm_correlation(df_returns, [('BTC', 'SHY'), ('ETH', 'SHY')],"USB ST ETF", span=30)

# %%
plot_ewm_correlation(df_returns, [('BTC', 'USO'), ('ETH', 'IEI')],"USB LT ETF", span=30)

# %%
plot_ewm_correlation(df_returns, [('BTC', 'SPY'), ('BTC', 'USO'),('BTC', 'SHY'), ('BTC', 'IEI')],"BTC", span=30)

# %%
plt.plot(bitcoin_price.sort_index().pct_change())
plt.plot(eth_price.sort_index().pct_change())

# %%
x = bitcoin_price.sort_index().pct_change().dropna()
y = eth_price.sort_index().pct_change().dropna()

# %%
len(df_returns)
# Out:
# 1509
